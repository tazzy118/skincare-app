# %%
#in case of any problems navigate to edit then notebook settings --> hardware accelerator, set it to gpu, and then click save.
#checks GPU status if using an NVIDIA graphics card.
#displays memory usage, temperature, and active processes.
#also useful for debugging GPU-related performance issues.
# !nvidia-smi
# Out:
# Thu May  8 00:31:49 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
#imports the os module, which handles operating system functions.
#gets the current working directory,which is useful when managing file paths dynamically.
#To make it easier to manage datasets images and models we create a HOME constant.
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
#installing Ultralytics library, which provides advanced object detection tools.
# This package includes YOLO models and simplifies deep learning workflows
# Required for running custom YOLO11 detection models
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.128 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.4/112.6 GB disk)

# %%
#create a directory named "datasets" inside the current working directory
#this will store the dataset files needed for training and testing
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow
#import the Roboflow module to interact with datasets using its API
from roboflow import Roboflow
#authenticate with the Roboflow API using an access key
#this grants permission to access and download the required dataset
rf = Roboflow(api_key="TgpEeIFcI6pkkBERf0U3")
#access the specific project within the skin disease workspace.
#this project contains skin disease images and annotations for model training
project = rf.workspace("skin-disease").project("skin-disease-vrvtv")
#selects version 6 of the dataset for downloading
#different versions may contain updates or improvements in data quality
version = project.version(6)
dataset = version.download("yolov11")
#the dataset will be saved locally for training object detection
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# Requirement already satisfied: roboflow in /usr/local/lib/python3.11/dist-packages (1.1.63)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.4.26)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.2.1)
# Requirement already satisfied: pillow-heif>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.22.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.4.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.57.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.1)
# loading Roboflow workspace...
# loading Roboflow project...

# %%
#modify the dataset configuration file (data.yaml) to adjust paths for training, validation, and testing
#the sed command deletes the last three lines of the file to remove unwanted entries.
# !sed -i '$d' {dataset.location}/data.yaml   #deletes the last line
# !sed -i '$d' {dataset.location}/data.yaml   #deletes the second to last line
# !sed -i '$d' {dataset.location}/data.yaml   #deletes the third to last line

#append new files path to specify where training, validattion & test images are located.
#the dataset's image directories are set correctly for YOLOv11 training
# !echo 'test: ../test/images' >> {dataset.location}/data.yaml
# !echo 'train: ../train/images' >> {dataset.location}/data.yaml
# !echo 'val: ../valid/images' >> {dataset.location}/data.yaml

#attempted modification to extend detection for hyperpigmentation. I just didnt have enough time to do this.
#adds a new class to data.yaml to differentiate hyperpigmentation from other skin conditions.
#the challenge hyperpigmentation lacks clear boundaries, making object detection difficult.

#!echo 'hyperpigmentation' >> {dataset.location}/data.yaml

#experimental preprocessing attempt: Enhance contrast to highlight pigmentation
#used CLAHE (Contrast Limited Adaptive Histogram Equalization) for better differentiation.
#https://stackoverflow.com/questions/39308030/how-do-i-increase-the-contrast-of-an-image-in-python-opencv

# import cv2
# def enhance_contrast(image_path):
#     img = cv2.imread(image_path, cv2.IMREAD_COLOR)
#     lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
#     l, a, b = cv2.split(lab)
#     clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
#     l = clahe.apply(l)
#     enhanced_img = cv2.merge((l, a, b))
#     return cv2.cvtColor(enhanced_img, cv2.COLOR_LAB2BGR)

#applying contrast enhancement to the test set (was explored, but not fully implemented)
# test_images = glob.glob(f'{dataset.location}/test/images/*.jpg')
# for img_path in test_images:
#     enhanced_img = enhance_contrast(img_path)
#     cv2.imwrite(img_path.replace('.jpg', '_enhanced.jpg'), enhanced_img)

#this approach was just an attempt but requires additional labeled hyperpigmentation samples for better accuracy.

# %% [markdown]
# ## Custom Training

# %%
#changes the current working directory back to the main project folder.
#this ensures that the training command runs in the correct directory
# %cd {HOME}

#training the YOLO11 model for object detection using the specified dataset.
#the training process includes the following;
# task=detect → Specifies that this is an object detection task
#mode=train → Indicates that the model is being trained
#model=yolo11s.pt → Uses the pretrained YOLO11 small model as the base
#data={dataset.location}/data.yaml → Loads dataset paths from the YAML configuration file
#epochs=10 → Trains the model for 10 epochs (adjust if more training is needed)
#imgsz=640 → Sets the image size to 640x640 pixels for input
#plots=True → Enables plotting of training metrics to visualize progress
# !yolo task=detect mode=train model=yolo11s.pt data={dataset.location}/data.yaml epochs=10 imgsz=640 plots=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11s.pt to 'yolo11s.pt'...
# 100% 18.4M/18.4M [00:00<00:00, 203MB/s]
# Ultralytics 8.3.128 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/datasets/Skin-Disease-6/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 24.5MB/s]
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    823278  ultralytics.nn.modules.head.Detect           [10, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,431,662 parameters, 9,431,646 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 97.5MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 775.0±452.7 MB/s, size: 22.8 KB)
# train: Scanning /content/datasets/Skin-Disease-6/train/labels... 2103 images, 9 backgrounds, 0 corrupt: 100% 2103/2103 [00:00<00:00, 2332.00it/s]
# train: New cache created: /content/datasets/Skin-Disease-6/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 135, len(boxes) = 4940. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 389.1±310.9 MB/s, size: 31.7 KB)
# val: Scanning /content/datasets/Skin-Disease-6/valid/labels... 266 images, 2 backgrounds, 0 corrupt: 100% 266/266 [00:00<00:00, 988.57it/s]
# val: New cache created: /content/datasets/Skin-Disease-6/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 62, len(boxes) = 595. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 10 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10         4G      2.011      4.659      2.205         25        640: 100% 132/132 [00:47<00:00,  2.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:04<00:00,  2.22it/s]
#                    all        266        595      0.376      0.168     0.0591       0.02
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10       4.8G      1.931      2.999      2.052         20        640: 100% 132/132 [00:42<00:00,  3.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:03<00:00,  2.87it/s]
#                    all        266        595      0.401       0.11       0.08     0.0298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      4.85G       1.91       2.79      2.075         14        640: 100% 132/132 [00:43<00:00,  3.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:02<00:00,  3.26it/s]
#                    all        266        595      0.396      0.121     0.0661     0.0241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      4.89G      1.876      2.624      2.029          8        640: 100% 132/132 [00:41<00:00,  3.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:02<00:00,  3.21it/s]
#                    all        266        595       0.22      0.185     0.0983     0.0328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      4.92G       1.82      2.495       1.98         17        640: 100% 132/132 [00:42<00:00,  3.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:02<00:00,  3.33it/s]
#                    all        266        595      0.536      0.139      0.119     0.0424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      4.97G      1.758      2.284      1.918         10        640: 100% 132/132 [00:45<00:00,  2.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:02<00:00,  3.45it/s]
#                    all        266        595       0.44      0.228      0.226     0.0981
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      5.01G       1.72      2.102      1.868         11        640: 100% 132/132 [00:41<00:00,  3.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:03<00:00,  2.32it/s]
#                    all        266        595      0.568      0.221      0.249     0.0955
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      5.04G      1.667       1.96      1.825         24        640: 100% 132/132 [00:41<00:00,  3.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:03<00:00,  2.90it/s]
#                    all        266        595      0.389      0.252      0.238     0.0957
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      5.09G      1.606      1.798      1.774         12        640: 100% 132/132 [00:41<00:00,  3.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:03<00:00,  2.97it/s]
#                    all        266        595      0.442       0.26      0.289      0.124
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      5.12G      1.564      1.663      1.742         37        640: 100% 132/132 [00:40<00:00,  3.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:02<00:00,  3.39it/s]
#                    all        266        595      0.375      0.287      0.261      0.109
#
# 10 epochs completed in 0.129 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 19.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 19.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.128 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,416,670 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:04<00:00,  2.06it/s]
#                    all        266        595      0.444       0.26      0.289      0.124
#                   Acne         20         67      0.317      0.164      0.137     0.0364
#      Atopic Dermatitis         24         42      0.492      0.119      0.175     0.0629
#           Chicken Skin         68         98          1          0      0.191     0.0853
#                 Eczema         27         51      0.325      0.353      0.354      0.149
# Hansen-s Disease-Leprosy         14         36      0.405      0.194      0.214     0.0992
# Hansen-s Disease-Leprosy- severe          5         21      0.579     0.0952      0.226     0.0861
#           Healthy skin         13         28          0          0     0.0177    0.00581
#              Psoriasis         37         87      0.376      0.345      0.301       0.13
#               Ringworm         21         30      0.367      0.767      0.746      0.366
#                  Warts         50        135      0.576      0.563      0.528      0.219
# Speed: 0.2ms preprocess, 4.7ms inference, 0.0ms loss, 4.8ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
#list the contents of the training output directory.
#this will display files generated during model training, including logs, checkpoints & evaluation results
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml			 PR_curve.png	   val_batch0_labels.jpg
# confusion_matrix_normalized.png  R_curve.png	   val_batch0_pred.jpg
# confusion_matrix.png		 results.csv	   val_batch1_labels.jpg
# F1_curve.png			 results.png	   val_batch1_pred.jpg
# labels_correlogram.jpg		 train_batch0.jpg  val_batch2_labels.jpg
# labels.jpg			 train_batch1.jpg  val_batch2_pred.jpg
# P_curve.png			 train_batch2.jpg  weights

# %%
#this allows visualisation of training results directly within the notebook interface.
from IPython.display import Image as IPyImage
# The confusion matrix helps evaluate model performance by showing accuracy across different classes.

# Key observations:
#background class has the highest correct detections (86), meaning the model is good at ignoring non skin elements.
#warts class has strong accuracy (75 correct), but some misclassified as ringworm and eczema.
#acne detection is weaker (9 correct), with 18 cases misclassified as background.The model struggles to differentiate acne from normal skin,
#likely due to subtle visual differences. More labeled acne images and improved preprocessing may enhance accuracy.
#healthy Skin only has 8 correct detections, suggesting the model struggles with normal skin identification.
#eczema shares visual characteristics with warts, causing detection errors. Better feature
#extraction or refining the models training data can help distinguish eczema accurately .

# Overall, acne and eczema detection require further optimization, particularly in training data diversity
# and distinguishing features between similar skin conditions. the model performs well on certain conditions like "Warts" and "Background," but struggles with
# distinguishing visually similar conditions. Improvements could include class balancing, more diverse training images,
# and refining preprocessing techniques
IPyImage(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)

# %%
#displays the training performance metrics as a set of line graphs
#helps analyze loss trends and improvements across 10 epochs

#key metrics:
#train/box_loss, train/cls_loss & train/dfl_loss measure loss during model training.
#val/box_loss, val/cls_loss & val/dfl_loss evaluates loss during validation.
#metrics/precision(B) shows how well the model detects skin conditions correctly.
#metrics/recall(B) indicates how many relevant conditions the model successfully identifies.
#metrics/mAP50(B) and metrics/mAP50-95(B) measures overall detection accuracy at different confidence thresholds.
# The blue line represents training progress, while the orange dashed line provides a smoothed trend.

from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/results.png', width=600)

# %%
#displays a batch of validation images with predicted bounding boxes.
#helps assess how well the YOLO11 model detects acne and eczema in real-world skin conditions.

#key observations:
#bounding boxes highlight detected regions for acne and eczema.
#confidence scores indicate how certain the model is about each classification.
#reviewing predictions can help identify misclassifications or missed detections.

from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)

# %%
#this step evaluates the models performance on unseen data to measure accuracy and reliability.

#task=detect specifies object detection mode. mode=val runs validation to assess model generalisation.
#model={HOME}/runs/detect/train/weights/best.pt uses the best-performing trained model.
#data={dataset.location}/data.yaml basically loads the dataset configuration for validation.
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.128 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,416,670 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1057.6±469.5 MB/s, size: 19.8 KB)
# val: Scanning /content/datasets/Skin-Disease-6/valid/labels.cache... 266 images, 2 backgrounds, 0 corrupt: 100% 266/266 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 62, len(boxes) = 595. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 17/17 [00:05<00:00,  3.25it/s]
#                    all        266        595      0.444       0.26      0.288      0.124
#                   Acne         20         67      0.312      0.164      0.136     0.0361
#      Atopic Dermatitis         24         42      0.497      0.119      0.176      0.063
#           Chicken Skin         68         98          1          0      0.188     0.0857
#                 Eczema         27         51      0.326      0.353      0.354      0.149
# Hansen-s Disease-Leprosy         14         36      0.408      0.194      0.214     0.0987
# Hansen-s Disease-Leprosy- severe          5         21      0.579     0.0952      0.221     0.0849
#           Healthy skin         13         28          0          0     0.0177    0.00579
#              Psoriasis         37         87      0.376      0.345        0.3       0.13
#               Ringworm         21         30      0.367      0.767      0.744      0.366
#                  Warts         50        135      0.574      0.563      0.528       0.22
# Speed: 2.2ms preprocess, 9.0ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#run object detection on test images using the trained model.
#the confidence threshold is set to 25% to filter low-confidence predictions.
#results will be saved for further evaluation.
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# Ultralytics 8.3.128 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,416,670 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/180 /content/datasets/Skin-Disease-6/test/images/07Acne081101_jpg.rf.0732d09e0029ff6423cafe6212a3ff2c.jpg: 640x640 (no detections), 15.6ms
# image 2/180 /content/datasets/Skin-Disease-6/test/images/0_20_jpg.rf.7934397d1be3e5425d22b1a9834aadaf.jpg: 640x640 (no detections), 15.6ms
# image 3/180 /content/datasets/Skin-Disease-6/test/images/10_11_jpg.rf.c1b65f26c7f7fd2ad490fb0759356249.jpg: 640x640 1 Psoriasis, 15.6ms
# image 4/180 /content/datasets/Skin-Disease-6/test/images/10_13_jpg.rf.040577e5913c1c598c82b323f5dfaf73.jpg: 640x640 3 Psoriasiss, 15.7ms
# image 5/180 /content/datasets/Skin-Disease-6/test/images/10_14_jpg.rf.c11b6f62c5e042eef1f729ea261639e6.jpg: 640x640 1 Atopic Dermatitis, 1 Warts, 15.6ms
# image 6/180 /content/datasets/Skin-Disease-6/test/images/10_22_jpg.rf.c44fcb3c12d6dc55d25ae97a18bd1313.jpg: 640x640 (no detections), 15.6ms
# image 7/180 /content/datasets/Skin-Disease-6/test/images/10_23_jpg.rf.5ede3c7832fd7afdfe8892d5ad23ce6a.jpg: 640x640 1 Eczema, 15.6ms
# image 8/180 /content/datasets/Skin-Disease-6/test/images/10_2_jpg.rf.cb8aecc826da4ab482d641331916f08e.jpg: 640x640 (no detections), 15.6ms
# image 9/180 /content/datasets/Skin-Disease-6/test/images/10_47_jpg.rf.1bb16f878cabe8d847ca8913d83d40c2.jpg: 640x640 1 Warts, 15.6ms
# image 10/180 /content/datasets/Skin-Disease-6/test/images/1200px-Keratosis_pilaris_-moderate-_jpg.rf.03e52c908c5916a96c0dcd4a69edd7d9.jpg: 640x640 1 Ringworm, 15.6ms
# image 11/180 /content/datasets/Skin-Disease-6/test/images/126_png.rf.35e82babc36bb27d9dc20e3805c66de6.jpg: 640x640 1 Ringworm, 12.2ms
# image 12/180 /content/datasets/Skin-Disease-6/test/images/127_6_19_jpg.rf.5180befd7629dd551a602bec5aef657f.jpg: 640x640 1 Atopic Dermatitis, 12.2ms
# image 13/180 /content/datasets/Skin-Disease-6/test/images/12_8_jpg.rf.4f9548b4013650b406cd4765183a562b.jpg: 640x640 1 Psoriasis, 12.2ms
# image 14/180 /content/datasets/Skin-Disease-6/test/images/18_21_jpg.rf.516c67f36167ca07e096102d28d74383.jpg: 640x640 (no detections), 12.2ms
# image 15/180 /content/datasets/Skin-Disease-6/test/images/1_77_jpg.rf.60a0a723ec9bbc6e0dd77e35a1352c01.jpg: 640x640 2 Atopic Dermatitiss, 12.2ms
# image 16/180 /content/datasets/Skin-Disease-6/test/images/2979-Keratosis_Pilaris-1296x728-slide2-1_jpg.rf.e0e3347a2b1359b8b13455606d7f1073.jpg: 640x640 1 Ringworm, 12.1ms
# image 17/180 /content/datasets/Skin-Disease-6/test/images/2_9_jpg.rf.e988058c7d113cca6a39ba9e8c4470ca.jpg: 640x640 (no detections), 12.2ms
# image 18/180 /content/datasets/Skin-Disease-6/test/images/3013__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd_jpg.rf.07bc3c1870f8604e1d5008dc8d7b4cce.jpg: 640x640 1 Ringworm, 12.2ms
# image 19/180 /content/datasets/Skin-Disease-6/test/images/3013__WatermarkedWyJXYXRlcm1hcmtlZCJd-1-_jpg.rf.ba0c1f535b59613a4295bf8d112883c6.jpg: 640x640 (no detections), 12.2ms
# image 20/180 /content/datasets/Skin-Disease-6/test/images/3013__WatermarkedWyJXYXRlcm1hcmtlZCJd-1-_jpg.rf.bd67cd84c44e7436dfb58b567ec1bfac.jpg: 640x640 (no detections), 15.4ms
# image 21/180 /content/datasets/Skin-Disease-6/test/images/3014__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.1761378367abb6894294930c78df7190.jpg: 640x640 1 Ringworm, 10.7ms
# image 22/180 /content/datasets/Skin-Disease-6/test/images/3015__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.76d98b1baac9e982d4d3b4d6570735b7.jpg: 640x640 1 Ringworm, 8.4ms
# image 23/180 /content/datasets/Skin-Disease-6/test/images/3016__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.a5f100a6fd514cc65360e2e1f86555b1.jpg: 640x640 1 Warts, 8.4ms
# image 24/180 /content/datasets/Skin-Disease-6/test/images/3017__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd_jpg.rf.5fd36959d7fe06d02057606e76767598.jpg: 640x640 (no detections), 8.4ms
# image 25/180 /content/datasets/Skin-Disease-6/test/images/3017__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.241efb9f482826bc4ca4e71f1a7878d6.jpg: 640x640 (no detections), 8.4ms
# image 26/180 /content/datasets/Skin-Disease-6/test/images/3018__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.ed2ce11856828999322d06adc9bf821f.jpg: 640x640 (no detections), 8.4ms
# image 27/180 /content/datasets/Skin-Disease-6/test/images/3019__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.791f8b408e9f6d398896eafaecd5679f.jpg: 640x640 1 Eczema, 8.4ms
# image 28/180 /content/datasets/Skin-Disease-6/test/images/3021__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.c960abe81c905884b2ed1f07acbcb28f.jpg: 640x640 (no detections), 8.4ms
# image 29/180 /content/datasets/Skin-Disease-6/test/images/3022__WatermarkedWyJXYXRlcm1hcmtlZCJd-1-_jpg.rf.33fd5987fb33da169efa580e4e9ea6fc.jpg: 640x640 (no detections), 8.3ms
# image 30/180 /content/datasets/Skin-Disease-6/test/images/3024__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.beeb09fbdc8b06cff38b8e118bbfdba3.jpg: 640x640 (no detections), 8.2ms
# image 31/180 /content/datasets/Skin-Disease-6/test/images/3024__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.d7afd1dc8936aa2d78a463a9a4cb0e0f.jpg: 640x640 (no detections), 8.2ms
# image 32/180 /content/datasets/Skin-Disease-6/test/images/3026__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.64951f0425c68246954b8bed70178395.jpg: 640x640 1 Ringworm, 8.2ms
# image 33/180 /content/datasets/Skin-Disease-6/test/images/3026__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.ad0a5a745b88c8ad916871bbf97ba4f8.jpg: 640x640 1 Ringworm, 9.9ms
# image 34/180 /content/datasets/Skin-Disease-6/test/images/3029__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.a199de5cea96a400043bbe67766c0b16.jpg: 640x640 (no detections), 8.8ms
# image 35/180 /content/datasets/Skin-Disease-6/test/images/3029__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf
# image 111/180 /content/datasets/Skin-Disease-6/test/images/images-77-_jpeg.rf.333063a548862ba0566b7a5090c7ab48.jpg: 640x640 (no detections), 12.4ms
# image 112/180 /content/datasets/Skin-Disease-6/test/images/images-79-_jpeg.rf.5a6afef3494b4b33aab0604fa40cab66.jpg: 640x640 1 Hansen-s Disease-Leprosy, 11.4ms
# image 113/180 /content/datasets/Skin-Disease-6/test/images/images-79-_jpeg.rf.c6cc3ded26a8890404e36166bb337d81.jpg: 640x640 1 Hansen-s Disease-Leprosy, 10.1ms
# image 114/180 /content/datasets/Skin-Disease-6/test/images/images-80-_jpeg.rf.f34f06c85b1ec11b73b50ea30fbea519.jpg: 640x640 (no detections), 10.0ms
# image 115/180 /content/datasets/Skin-Disease-6/test/images/images-82-_jpeg.rf.e517a7b860b6a299202ef54db54fcb64.jpg: 640x640 (no detections), 14.3ms
# image 116/180 /content/datasets/Skin-Disease-6/test/images/images-85-_jpeg.rf.c449cc1cbaf7c4b5c500fa92b87ae1bf.jpg: 640x640 (no detections), 10.6ms
# image 117/180 /content/datasets/Skin-Disease-6/test/images/images-87-_jpeg.rf.ddd895f8890ca933f299b77845d31327.jpg: 640x640 (no detections), 10.6ms
# image 118/180 /content/datasets/Skin-Disease-6/test/images/images-88-_jpeg.rf.d4a8f150d698e838b7b90db60a71d8e1.jpg: 640x640 (no detections), 10.9ms
# image 119/180 /content/datasets/Skin-Disease-6/test/images/images-90-_jpeg.rf.14710eae2e3264665f4f8d9ce8c5d61a.jpg: 640x640 (no detections), 10.9ms
# image 120/180 /content/datasets/Skin-Disease-6/test/images/images-91-_jpeg.rf.39b259b9176be583376d0d0fcdd8e109.jpg: 640x640 (no detections), 10.7ms
# image 121/180 /content/datasets/Skin-Disease-6/test/images/images-92-_jpeg.rf.8b995b631d3df2b0cb34c88000c68937.jpg: 640x640 (no detections), 10.7ms
# image 122/180 /content/datasets/Skin-Disease-6/test/images/images-93-_jpeg.rf.92899ccdda1b297165ed8e281cdb7e6a.jpg: 640x640 1 Ringworm, 10.9ms
# image 123/180 /content/datasets/Skin-Disease-6/test/images/images-93-_jpeg.rf.bdce14d5c2fe93ef1c978d7da381019c.jpg: 640x640 1 Ringworm, 10.8ms
# image 124/180 /content/datasets/Skin-Disease-6/test/images/images-94-_jpeg.rf.d4c451fca4d183bc2ff0508935f2d3aa.jpg: 640x640 (no detections), 11.2ms
# image 125/180 /content/datasets/Skin-Disease-6/test/images/images-95-_jpeg.rf.fefffe8ee7558ec4d07b7445eae301b2.jpg: 640x640 (no detections), 13.6ms
# image 126/180 /content/datasets/Skin-Disease-6/test/images/images-96-_jpeg.rf.7258baba748058c94690f0a07240388e.jpg: 640x640 (no detections), 10.5ms
# image 127/180 /content/datasets/Skin-Disease-6/test/images/images-97-_jpeg.rf.06a7d7608345aa4328b92d716e9e3def.jpg: 640x640 (no detections), 10.5ms
# image 128/180 /content/datasets/Skin-Disease-6/test/images/images-97-_jpeg.rf.ccf45832fedb7a59d97a03bc961caea6.jpg: 640x640 (no detections), 10.7ms
# image 129/180 /content/datasets/Skin-Disease-6/test/images/images_jpg.rf.2f37a00c9770075167fa6b7488dc5801.jpg: 640x640 (no detections), 10.7ms
# image 130/180 /content/datasets/Skin-Disease-6/test/images/istockphoto-1164733368-612x612_jpg.rf.8b82971f519893d05e54e93b8b1b14f8.jpg: 640x640 2 Ringworms, 10.3ms
# image 131/180 /content/datasets/Skin-Disease-6/test/images/istockphoto-1178715749-612x612_jpg.rf.dd60d48201e7bb15a291a15c5d3ff1a3.jpg: 640x640 (no detections), 10.9ms
# image 132/180 /content/datasets/Skin-Disease-6/test/images/istockphoto-1178715752-612x612_jpg.rf.809ef5d9c275973ab188615fe012afcc.jpg: 640x640 (no detections), 10.3ms
# image 133/180 /content/datasets/Skin-Disease-6/test/images/istockphoto-1222618940-612x612_jpg.rf.fc159674c88912d98cc36050681a0dcf.jpg: 640x640 (no detections), 10.4ms
# image 134/180 /content/datasets/Skin-Disease-6/test/images/keratosis-pilaris-1-_jpg.rf.2183da26a8b4c14c6af82f76ca032eb9.jpg: 640x640 1 Ringworm, 10.8ms
# image 135/180 /content/datasets/Skin-Disease-6/test/images/leprosy-histoid-00001__WatermarkedWyJXYXRlcm1hcmtlZCJd_jpg.rf.cf8fe8a3aed29b2743bb8df255eefaf2.jpg: 640x640 (no detections), 10.3ms
# image 136/180 /content/datasets/Skin-Disease-6/test/images/pigmentation_0_6418_jpeg.rf.2a8ec7f3ab3d186295fbb1b55a7590c2.jpg: 640x640 (no detections), 10.4ms
# image 137/180 /content/datasets/Skin-Disease-6/test/images/ringworm-5-_jpg.rf.500a2df5de5818c67e8d17ea8a288257.jpg: 640x640 1 Ringworm, 10.2ms
# image 138/180 /content/datasets/Skin-Disease-6/test/images/ringworm-cebd68_jpg.rf.f306ab95d86ec18e9f5281e7ae7aaef3.jpg: 640x640 1 Ringworm, 13.5ms
# image 139/180 /content/datasets/Skin-Disease-6/test/images/t-Psoriasis-Chronic-Plaque-118_jpg.rf.ae13edeaea0a56e990612b55848899dd.jpg: 640x640 2 Psoriasiss, 11.1ms
# image 140/180 /content/datasets/Skin-Disease-6/test/images/t-Psoriasis-Chronic-Plaque-129_jpg.rf.f8a69f1c1855c9685028fe29d97afeb1.jpg: 640x640 3 Psoriasiss, 9.9ms
# image 141/180 /content/datasets/Skin-Disease-6/test/images/t-Psoriasis-Chronic-Plaque-135_jpg.rf.bfdbc3362fe67a734ea69ed930c2957e.jpg: 640x640 2 Psoriasiss, 9.7ms
# image 142/180 /content/datasets/Skin-Disease-6/test/images/t-Psoriasis-Chronic-Plaque-141_jpg.rf.3fc47d040db7d943d2c78ccaee0417dd.jpg: 640x640 2 Eczemas, 2 Psoriasiss, 9.7ms
# image 143/180 /content/datasets/Skin-Disease-6/test/images/t-Psoriasis-Chronic-Plaque-145_jpg.rf.8f2e471a2212cfb6b51932881c7ad35f.jpg: 640x640 (no detections), 9.9ms
# image 144/180 /content/datasets/Skin-Disease-6/test/images/t-Psoriasis-Chronic-Plaque-18_jpg.rf.a5055b149d67e527b2e7d57ffd739425.jpg: 640x640 1 Psoriasis, 14.8ms
# image 145/180 /content/datasets/Skin-Disease-6/test/images/t-Psoriasis-Hand-58_jpg.rf.e4471cdc4d545ea43812bb051d6e8695.jpg: 640x640 4 Psoriasiss, 16.5ms
# image 146/180 /content/datasets/Skin-Disease-6/test/images/t-eczema
# image 166/180 /content/datasets/Skin-Disease-6/test/images/t-warts-15_jpg.rf.af38dbdb7b396a19e6f9a99e892e9c45.jpg: 640x640 1 Warts, 13.4ms
# image 167/180 /content/datasets/Skin-Disease-6/test/images/t-warts-39_jpg.rf.28577f4ce5ae587aa2da6e4100d6a566.jpg: 640x640 2 Wartss, 12.2ms
# image 168/180 /content/datasets/Skin-Disease-6/test/images/t-warts-common-29_jpg.rf.41fa67cb791c9f0da60519b3591dcde3.jpg: 640x640 3 Wartss, 12.0ms
# image 169/180 /content/datasets/Skin-Disease-6/test/images/t-warts-common-71_jpg.rf.06865c158111c742aa21b00cb095961f.jpg: 640x640 1 Warts, 16.8ms
# image 170/180 /content/datasets/Skin-Disease-6/test/images/t-warts-cryotherapy-8_jpg.rf.939a63ee78b0acfa10405fc177de6ddd.jpg: 640x640 2 Psoriasiss, 11.2ms
# image 171/180 /content/datasets/Skin-Disease-6/test/images/t-warts-digitate-56_jpg.rf.ebadd5b15ce6ad2d0a1cfa2eecab5930.jpg: 640x640 (no detections), 10.6ms
# image 172/180 /content/datasets/Skin-Disease-6/test/images/t-warts-digitate-57_jpg.rf.21093d2eb5c473ca84347fc38ac5b57f.jpg: 640x640 2 Wartss, 13.9ms
# image 173/180 /content/datasets/Skin-Disease-6/test/images/t-warts-digitate-6_jpg.rf.6fa5904db6618134a3035bf12eff2a6d.jpg: 640x640 1 Eczema, 12.7ms
# image 174/180 /content/datasets/Skin-Disease-6/test/images/t-warts-flat-38_jpg.rf.96103742ffb010ab4b2047d54e865e1b.jpg: 640x640 2 Wartss, 11.5ms
# image 175/180 /content/datasets/Skin-Disease-6/test/images/t-warts-plantar-43_jpg.rf.37e5635836e057d78ef45222e44365ee.jpg: 640x640 1 Warts, 10.4ms
# image 176/180 /content/datasets/Skin-Disease-6/test/images/t-warts-plantar-61_jpg.rf.de80a1e1683eeff0e7db511d9db5d4fe.jpg: 640x640 5 Wartss, 15.6ms
# image 177/180 /content/datasets/Skin-Disease-6/test/images/t-warts-plantar-66_jpg.rf.9eeb35927611eaee4ad2d8b80b3805da.jpg: 640x640 1 Warts, 12.1ms
# image 178/180 /content/datasets/Skin-Disease-6/test/images/tinea-corporis_jpg.rf.2b9318ec892c2644d25dc73bfef9db2c.jpg: 640x640 1 Ringworm, 15.4ms
# image 179/180 /content/datasets/Skin-Disease-6/test/images/v-stasis-dermatitis-156_jpg.rf.1d4f879fcab17d1783c3e7681b0208b6.jpg: 640x640 1 Eczema, 15.6ms
# image 180/180 /content/datasets/Skin-Disease-6/test/images/v-stasis-dermatitis-2_jpg.rf.8ca49f1b0483850a84417723d6f09f03.jpg: 640x640 1 Psoriasis, 14.8ms
# Speed: 3.0ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# Let's take a look at few results.

# %%
#import necessary libraries for retrieving and displaying prediction images.
#glob finds files matching a specific pattern.
import glob
import os
from IPython.display import Image as IPyImage, display

#identifys the latest prediction folder based on modification time.
#makes sure the script always fetches the most recent set of detection results.
latest_folder = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)

#loop through the first three prediction images and display them.
#helps visualise the detection results generated by YOLO11.
for img in glob.glob(f'{latest_folder}/*.jpg')[:3]:
    display(IPyImage(filename=img, width=600))
    print("\n")  #this will give space between images for better readability.
